# %%
import numpy as np
np.random.seed(888)
nodes=8
J=np.zeros((nodes,nodes))
J[0,1]=-1
J[0,4]=-1
J[0,7]=-1
J[1,0]=-1
J[1,2]=-1
J[1,5]=-1
J[2,1]=-1
J[2,3]=-1
J[2,6]=-1
J[3,2]=-1
J[3,4]=-1
J[3,7]=-1
J[4,3]=-1
J[4,5]=-1
J[4,0]=-1
J[5,6]=-1
J[5,1]=-1
J[5,4]=-1
J[6,7]=-1
J[6,2]=-1
J[6,5]=-1
J[7,0]=-1
J[7,3]=-1
J[7,6]=-1

# %%
# -*- coding: utf-8 -*-
"""
Created on Sat Jan  2 00:55:27 2021

"""

import math
#from scipy.integrate import odeint
import matplotlib.pyplot as plt
plt.rcParams["figure.figsize"] = (8,5.5)
t0=0
tf=50
Ks=1
#write the function t
#use dt =
natf=0.1
def f(x,d_t=0):
    # A1= 4
    # A2= 4
    # A3= 1
    # A4= 1
    # A5= 1
    # A6= 1

    f1= natf
    f2= natf
    f3= natf
    f4= natf
    f5= natf
    f6= natf
    f7=natf
    f8=natf
    fpet=20

    k12=0
    kmn=1

    phi1 = x[0]
    phi2 = x[1]
    phi3 = x[2]
    phi4 = x[3]
    phi5 = x[4]
    phi6 = x[5]
    phi7=x[6]
    phi8=x[7]
    phi_i, phi_j = np.meshgrid(x, x)
    # temp = J*np.sin(phi_j - phi_i)+(Ks/K)*np.sin(2*nat_freq*t-phi_i)
    # dphi_dt =  nat_freq+ K*temp.sum(axis=0)

    # dphi1dt = (f1 - np.sin(phi2-phi1)-np.sin(phi5-phi1)-np.sin(phi8-phi1)-Ks*np.sin(2*np.pi*2*f1*d_t-phi1))* 2*math.pi
    # dphi2dt = (f2 - np.sin(phi3-phi2)-np.sin(phi6-phi2)-np.sin(phi1-phi2)-Ks*np.sin(2*np.pi*2*f1*d_t-phi2))* 2*math.pi
    # dphi3dt=  (f3 - np.sin(phi4-phi3)-np.sin(phi7-phi3)-np.sin(phi2-phi3)-Ks*np.sin(2*np.pi*2*f1*d_t-phi3))* 2*math.pi
    # dphi4dt=  (f4 - np.sin(phi5-phi4)-np.sin(phi8-phi4)-np.sin(phi3-phi4)-Ks*np.sin(2*np.pi*2*f1*d_t-phi4))* 2*math.pi
    # dphi5dt=  (f5 - np.sin(phi6-phi5)-np.sin(phi1-phi5)-np.sin(phi4-phi5)-Ks*np.sin(2*np.pi*2*f1*d_t-phi5))* 2*math.pi
    # dphi6dt=  (f6 - np.sin(phi7-phi6)-np.sin(phi2-phi6)-np.sin(phi5-phi6)-Ks*np.sin(2*np.pi*2*f1*d_t-phi6))* 2*math.pi
    # dphi7dt=  (f7 - np.sin(phi8-phi7)-np.sin(phi3-phi7)-np.sin(phi6-phi7)-Ks*np.sin(2*np.pi*2*f1*d_t-phi7))* 2*math.pi
    # dphi8dt=  (f8 - np.sin(phi1-phi8)-np.sin(phi4-phi8)-np.sin(phi7-phi8)-Ks*np.sin(2*np.pi*2*f1*d_t-phi8))* 2*math.pi


    # dphi1dt = (f1 - np.sin(phi2-phi1)-np.sin(phi5-phi1)-np.sin(phi8-phi1)-Ks*np.sin(2*np.pi*2*f1*d_t-phi1))
    # dphi2dt = (f2 - np.sin(phi3-phi2)-np.sin(phi6-phi2)-np.sin(phi1-phi2)-Ks*np.sin(2*np.pi*2*f1*d_t-phi2))
    # dphi3dt=  (f3 - np.sin(phi4-phi3)-np.sin(phi7-phi3)-np.sin(phi2-phi3)-Ks*np.sin(2*np.pi*2*f1*d_t-phi3))
    # dphi4dt=  (f4 - np.sin(phi5-phi4)-np.sin(phi8-phi4)-np.sin(phi3-phi4)-Ks*np.sin(2*np.pi*2*f1*d_t-phi4))
    # dphi5dt=  (f5 - np.sin(phi6-phi5)-np.sin(phi1-phi5)-np.sin(phi4-phi5)-Ks*np.sin(2*np.pi*2*f1*d_t-phi5))
    # dphi6dt=  (f6 - np.sin(phi7-phi6)-np.sin(phi2-phi6)-np.sin(phi5-phi6)-Ks*np.sin(2*np.pi*2*f1*d_t-phi6))
    # dphi7dt=  (f7 - np.sin(phi8-phi7)-np.sin(phi3-phi7)-np.sin(phi6-phi7)-Ks*np.sin(2*np.pi*2*f1*d_t-phi7))
    # dphi8dt=  (f8 - np.sin(phi1-phi8)-np.sin(phi4-phi8)-np.sin(phi7-phi8)-Ks*np.sin(2*np.pi*2*f1*d_t-phi8))

    # dphi1dt = (f1 - np.sin(phi2-phi1)-np.sin(phi5-phi1)-np.sin(phi8-phi1)-Ks*np.sin(2*phi1))* 2*math.pi
    # dphi2dt = (f2 - np.sin(phi3-phi2)-np.sin(phi6-phi2)-np.sin(phi1-phi2)-Ks*np.sin(2*phi2))* 2*math.pi
    # dphi3dt=  (f3 - np.sin(phi4-phi3)-np.sin(phi7-phi3)-np.sin(phi2-phi3)-Ks*np.sin(2*phi3))* 2*math.pi
    # dphi4dt=  (f4 - np.sin(phi5-phi4)-np.sin(phi8-phi4)-np.sin(phi3-phi4)-Ks*np.sin(2*phi4))* 2*math.pi
    # dphi5dt=  (f5 - np.sin(phi6-phi5)-np.sin(phi1-phi5)-np.sin(phi4-phi5)-Ks*np.sin(2*phi5))* 2*math.pi
    # dphi6dt=  (f6 - np.sin(phi7-phi6)-np.sin(phi2-phi6)-np.sin(phi5-phi6)-Ks*np.sin(2*phi6))* 2*math.pi
    # dphi7dt=  (f7 - np.sin(phi8-phi7)-np.sin(phi3-phi7)-np.sin(phi6-phi7)-Ks*np.sin(2*phi7))* 2*math.pi
    # dphi8dt=  (f8 - np.sin(phi1-phi8)-np.sin(phi4-phi8)-np.sin(phi7-phi8)-Ks*np.sin(2*phi8))* 2*math.pi



    # sin(2phi)
    dphi1dt = (f1 - np.sin(phi2-phi1)-np.sin(phi5-phi1)-np.sin(phi8-phi1)-Ks*np.sin(2*phi1))
    dphi2dt = (f2 - np.sin(phi3-phi2)-np.sin(phi6-phi2)-np.sin(phi1-phi2)-Ks*np.sin(2*phi2))
    dphi3dt=  (f3 - np.sin(phi4-phi3)-np.sin(phi7-phi3)-np.sin(phi2-phi3)-Ks*np.sin(2*phi3))
    dphi4dt=  (f4 - np.sin(phi5-phi4)-np.sin(phi8-phi4)-np.sin(phi3-phi4)-Ks*np.sin(2*phi4))
    dphi5dt=  (f5 - np.sin(phi6-phi5)-np.sin(phi1-phi5)-np.sin(phi4-phi5)-Ks*np.sin(2*phi5))
    dphi6dt=  (f6 - np.sin(phi7-phi6)-np.sin(phi2-phi6)-np.sin(phi5-phi6)-Ks*np.sin(2*phi6))
    dphi7dt=  (f7 - np.sin(phi8-phi7)-np.sin(phi3-phi7)-np.sin(phi6-phi7)-Ks*np.sin(2*phi7))
    dphi8dt=  (f8 - np.sin(phi1-phi8)-np.sin(phi4-phi8)-np.sin(phi7-phi8)-Ks*np.sin(2*phi8))


    # dphi1dt = (f1 - np.sin(phi2-phi1)-np.sin(phi5-phi1)-np.sin(phi8-phi1)-Ks*np.sin(2*f1*d_t-phi1))
    # dphi2dt = (f2 - np.sin(phi3-phi2)-np.sin(phi6-phi2)-np.sin(phi1-phi2)-Ks*np.sin(2*f1*d_t-phi2))
    # dphi3dt=  (f3 - np.sin(phi4-phi3)-np.sin(phi7-phi3)-np.sin(phi2-phi3)-Ks*np.sin(2*f1*d_t-phi3))
    # dphi4dt=  (f4 - np.sin(phi5-phi4)-np.sin(phi8-phi4)-np.sin(phi3-phi4)-Ks*np.sin(2*f1*d_t-phi4))
    # dphi5dt=  (f5 - np.sin(phi6-phi5)-np.sin(phi1-phi5)-np.sin(phi4-phi5)-Ks*np.sin(2*f1*d_t-phi5))
    # dphi6dt=  (f6 - np.sin(phi7-phi6)-np.sin(phi2-phi6)-np.sin(phi5-phi6)-Ks*np.sin(2*f1*d_t-phi6))
    # dphi7dt=  (f7 - np.sin(phi8-phi7)-np.sin(phi3-phi7)-np.sin(phi6-phi7)-Ks*np.sin(2*f1*d_t-phi7))
    # dphi8dt=  (f8 - np.sin(phi1-phi8)-np.sin(phi4-phi8)-np.sin(phi7-phi8)-Ks*np.sin(2*f1*d_t-phi8))



    return [dphi1dt,dphi2dt,dphi3dt,dphi4dt,dphi5dt,dphi6dt,dphi7dt,dphi8dt]

x0=np.random.random(8)
t=np.linspace(t0,tf,num=12000)
deltat= t[1] -t[0]

phi1f = np.linspace(t0,tf,num=12000)
phi2f = np.linspace(t0,tf,num=12000)
phi3f = np.linspace(t0,tf,num=12000)
phi4f = np.linspace(t0,tf,num=12000)
phi5f = np.linspace(t0,tf,num=12000)
phi6f = np.linspace(t0,tf,num=12000)
phi7f = np.linspace(t0,tf,num=12000)
phi8f = np.linspace(t0,tf,num=12000)

dphi1f = np.linspace(t0,tf,num=12000)
dphi2f = np.linspace(t0,tf,num=12000)
dphi3f = np.linspace(t0,tf,num=12000)
dphi4f = np.linspace(t0,tf,num=12000)
dphi5f = np.linspace(t0,tf,num=12000)
dphi6f = np.linspace(t0,tf,num=12000)
dphi7f = np.linspace(t0,tf,num=12000)
dphi8f = np.linspace(t0,tf,num=12000)

phi1f[0] = x0[0]
phi2f[0] = x0[1]
phi3f[0] = x0[2]
phi4f[0] = x0[3]
phi5f[0] = x0[4]
phi6f[0] = x0[5]
phi7f[0] = x0[6]
phi8f[0] = x0[7]

x01= f(x0)
dphi1f[0] = x01[0]
dphi2f[0] = x01[1]
dphi3f[0] = x01[2]
dphi4f[0] = x01[3]
dphi5f[0] = x01[4]
dphi6f[0] = x01[5]
dphi8f[0] = x01[6]
dphi7f[0] = x01[7]

for i in range(len(t)-1):
    x2 = f([phi1f[i],phi2f[i],phi3f[i],phi4f[i],phi5f[i],phi6f[i],phi7f[i],phi8f[i]],i*deltat)
    phi1f[i+1] = phi1f[i] + dphi1f[i] * deltat
    phi2f[i+1] = phi2f[i] + dphi2f[i] * deltat
    phi3f[i+1] = phi3f[i] + dphi3f[i] * deltat
    phi4f[i+1] = phi4f[i] + dphi4f[i] * deltat
    phi5f[i+1] = phi5f[i] + dphi5f[i] * deltat
    phi6f[i+1] = phi6f[i] + dphi6f[i] * deltat
    phi7f[i+1] = phi7f[i] + dphi7f[i] * deltat
    phi8f[i+1] = phi8f[i] + dphi8f[i] * deltat

    #x3 = f(phi1f[i+1], t[i+1])
    x3 = f([phi1f[i+1],phi2f[i+1],phi3f[i+1],phi4f[i+1],phi5f[i+1],phi6f[i+1],phi7f[i+1],phi8f[i+1]],i*deltat)
    dphi1f[i+1] = x3[0]
    dphi2f[i+1] = x3[1]
    dphi3f[i+1] = x3[2]
    dphi4f[i+1] = x3[3]
    dphi5f[i+1] = x3[4]
    dphi6f[i+1] = x3[5]
    dphi7f[i+1] = x3[6]
    dphi8f[i+1] = x3[7]


plt.plot(t, dphi1f/(2*math.pi), label="dphi1/dt")
plt.plot(t, dphi2f/(2*math.pi), label="dphi2/dt")
plt.plot(t, dphi3f/(2*math.pi), label="dphi3/dt")
plt.plot(t, dphi4f/(2*math.pi), label="dphi4/dt")
plt.plot(t, dphi5f/(2*math.pi), label="dphi5/dt")
plt.plot(t, dphi6f/(2*math.pi), label="dphi6/dt")
plt.plot(t, dphi7f/(2*math.pi), label="dphi7/dt")
plt.plot(t, dphi8f/(2*math.pi), label="dphi8/dt")

plt.xlabel('Time(s)')
plt.ylabel('Frequency(Hz)')
plt.title('Figure 2- Math ODE: 1/2pi(dphi/dt)')
#plt.legend(loc='best')
leg = plt.legend( loc = 'upper right')
#plt.label(loc = 'upper right')

plt.show()

# %%
plt.rcParams["figure.figsize"] = (20,15)

plt.plot(t, phi1f/np.pi, label=r'$\phi_1$',linewidth=8)
plt.plot(t, phi2f/np.pi, label=r'$\phi_2$',linewidth=8)
plt.plot(t, phi3f/np.pi, label=r'$\phi_3$',linewidth=8)
plt.plot(t, phi4f/np.pi, label=r'$\phi_4$',linewidth=8)
plt.plot(t, phi5f/np.pi, label=r'$\phi_5$',linewidth=8)
plt.plot(t, phi6f/np.pi, label=r'$\phi_6$',linewidth=8)
plt.plot(t, phi7f/np.pi, label=r'$\phi_7$',linewidth=8)
plt.plot(t, phi8f/np.pi, label=r'$\phi_8$',linewidth=8)
plt.legend(prop={'size': 40},loc='center right')
plt.title("Phase vs Time for a size-8 MAX-CUT problem",size=50,fontweight="bold")
plt.xlabel("Timesteps",size=50,fontweight="bold")
plt.ylabel(r'$\phi$ (normalised by $\pi$)',size=50)
plt.yticks(fontsize=45)

plt.xticks(fontsize=45)
from google.colab import files
plt.savefig("8cut.png")
vals=np.zeros(nodes)
vals[0]=np.sin(phi1f[-1])
vals[1]=np.sin(phi2f[-1])
vals[2]=np.sin(phi3f[-1])
vals[3]=np.sin(phi4f[-1])
vals[4]=np.sin(phi5f[-1])
vals[5]=np.sin(phi6f[-1])
vals[6]=np.sin(phi7f[-1])
vals[7]=np.sin(phi8f[-1])
print(vals)
# Out:
# [-0.05006278 -0.05006278  0.05006278 -0.05006278  0.05006278  0.05006278
#  -0.05006278  0.05006278]

# %%
files.download("8cut.png")

# %%
#plt.plot(t, phi1f, label="phi1")
plt.rcParams["figure.figsize"] = (30,20)

phi_diff=phi1f
plt.plot(t, (phi2f-phi_diff)/np.pi, label=r'$\phi_2-\phi_1$')
plt.plot(t, (phi3f-phi_diff)/np.pi, label=r'$\phi_3-\phi_1$')
plt.plot(t, (phi4f-phi_diff)/np.pi, label=r'$\phi_4-\phi_1$')
plt.plot(t, (phi5f-phi_diff)/np.pi, label=r'$\phi_5-\phi_1$')
plt.plot(t, (phi6f-phi_diff)/np.pi, label=r'$\phi_6-\phi_1$')
plt.plot(t, (phi7f-phi_diff)/np.pi, label=r'$\phi_7-\phi_1$')
plt.plot(t, (phi8f-phi_diff)/np.pi, label=r'$\phi_8-\phi_1$')
plt.legend(prop={'size': 30})
plt.title("Phase difference vs Time with natural frequency 10 Hz",size=30)

plt.grid()
